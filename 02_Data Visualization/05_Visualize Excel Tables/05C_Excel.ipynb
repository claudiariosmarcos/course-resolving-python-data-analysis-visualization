# %% [markdown]
# # Data Visualizations with Excel Data Tables

# %% [markdown]
# ## Load Excel in Python
#
# - gapminder.xlsx

# %%
import pandas
df_countries = pandas.read_excel('gapminder.xlsx')

# %%
df_countries
# Out:
#                 country  life_expectancy  money_per_person
# 0           Afghanistan           43.828        974.580338
# 1               Albania           76.423       5937.029526
# 2               Algeria           72.301       6223.367465
# 3                Angola           42.731       4797.231267
# 4             Argentina           75.320      12779.379640
# ..                  ...              ...               ...
# 137             Vietnam           74.249       2441.576404
# 138  West Bank and Gaza           73.422       3025.349798
# 139         Yemen, Rep.           62.698       2280.769906
# 140              Zambia           42.384       1271.211593
# 141            Zimbabwe           43.487        469.709298
#
# [142 rows x 3 columns]

# %% [markdown]
# ## Create a scatter plot

# %% [markdown]
# ### Import matplotlib library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Access column data separately

# %%
df_countries.money_per_person
# Out:
# 0        974.580338
# 1       5937.029526
# 2       6223.367465
# 3       4797.231267
# 4      12779.379640
#            ...
# 137     2441.576404
# 138     3025.349798
# 139     2280.769906
# 140     1271.211593
# 141      469.709298
# Name: money_per_person, Length: 142, dtype: float64

# %% [markdown]
# ### Pass data to scatter function

# %%
plt.scatter(x = df_countries.life_expectancy,y = df_countries.money_per_person)

# %% [markdown]
# ## Customize the plot

# %% [markdown]
# ### Change the size

# %%
plt.scatter(x = df_countries.life_expectancy,y = df_countries.money_per_person, s=5)

# %% [markdown]
# ### Change the color

# %%
plt.scatter(x = df_countries.life_expectancy,y = df_countries.money_per_person,c='purple')

# %% [markdown]
# ### Change the marker

# %%
plt.scatter(x = df_countries.life_expectancy,y = df_countries.money_per_person,marker='x')

# %% [markdown]
# ### Change the border

# %%
plt.scatter(x = df_countries.life_expectancy,y = df_countries.money_per_person,edgecolors='red')

# %% [markdown]
# ## Interactive scatter plot
#
# Which country represents each point?

# %% [markdown]
# ### Import plotly library

# %%
import plotly.express as px

# %% [markdown]
# ### Pass data to scatter function

# %%
px.scatter()

# %% [markdown]
# ### Add data to hovering

# %% [markdown]
# ## Data Analysis
#
# - [ ] What is the relationship between money_per_person (x-axis) and life_expectancy (y-axis)?
